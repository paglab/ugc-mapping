# %%
import os
import json
import numpy as np
from PIL import Image
from pycocotools.coco import COCO

# 定义自定义类别及其对应的ID映射，去掉背景类
categories = ["grass", "herb", "litter", "soil", "stone", "wood", "woodchip"]
category_id_mapping = {category: idx + 1 for idx, category in enumerate(categories)}

# 定义类别ID到颜色的映射（去掉背景类的颜色）
category_colors = {
    1: (128, 0, 0),       # grass - 深红色
    2: (0, 128, 0),       # herb - 深绿色
    3: (128, 128, 0),     # litter - 橄榄色
    4: (0, 0, 128),       # soil - 深蓝色
    5: (128, 0, 128),     # stone - 紫色
    6: (0, 128, 128),     # wood - 青色
    7: (128, 128, 128)    # woodchip - 灰色
}

def apply_color_map(seg_mask, category_colors):
    height, width = seg_mask.shape
    color_mask = np.zeros((height, width, 3), dtype=np.uint8)
    
    for category_id, color in category_colors.items():
        color_mask[seg_mask == category_id] = color
    
    return color_mask

def coco_to_voc_segmentation(coco_annotation_file, coco_image_dir, output_dir, category_id_mapping, category_colors):
    os.makedirs(output_dir, exist_ok=True)
    os.makedirs(os.path.join(output_dir, "JPEGImages"), exist_ok=True)
    os.makedirs(os.path.join(output_dir, "SegmentationClass"), exist_ok=True)
    os.makedirs(os.path.join(output_dir, "SegmentationClassVisualization"), exist_ok=True)
    
    # 加载COCO标注文件
    coco = COCO(coco_annotation_file)
    
    for img_id in coco.getImgIds():
        # 加载图像信息
        img_info = coco.loadImgs(img_id)[0]
        img_file = os.path.join(coco_image_dir, img_info['file_name'])
        
        # 复制图像到JPEGImages目录
        img = Image.open(img_file).convert("RGB")
        img.save(os.path.join(output_dir, "JPEGImages", img_info['file_name']))
        
        # 准备分割掩码，初始化为0（未标注的区域保持为0）
        seg_mask = np.zeros((img_info['height'], img_info['width']), dtype=np.uint8)

        # 获取该图像的所有标注
        ann_ids = coco.getAnnIds(imgIds=img_id, iscrowd=None)
        anns = coco.loadAnns(ann_ids)
        
        for ann in anns:
            category_name = coco.loadCats(ann['category_id'])[0]['name']
            category_id = category_id_mapping.get(category_name)
            
            if category_id is not None:
                mask = coco.annToMask(ann)
                seg_mask[mask == 1] = category_id
        
        # 检查生成的掩码中包含哪些类别
        unique_values = np.unique(seg_mask)
        print(f"Image {img_info['file_name']} contains category IDs: {unique_values}")
        
        # 保存原始分割掩码为PNG格式
        seg_img = Image.fromarray(seg_mask)
        seg_img.save(os.path.join(output_dir, "SegmentationClass", img_info['file_name'].replace('.jpg', '.png')))
        
        # 生成彩色分割掩码用于可视化
        color_mask = apply_color_map(seg_mask, category_colors)
        color_mask_img = Image.fromarray(color_mask)
        color_mask_img.save(os.path.join(output_dir, "SegmentationClassVisualization", img_info['file_name']))
        
        print(f"Processed {img_info['file_name']}")

if __name__ == "__main__":
    # 示例使用
    coco_annotation_file = "/Users/lu/awesome-semantic-segmentation-pytorch/scripts/coco/annotations.json"  # COCO标注文件路径
    coco_image_dir = "/Users/lu/awesome-semantic-segmentation-pytorch/scripts/coco"                       # COCO图像文件夹路径
    output_dir = "/Users/lu/awesome-semantic-segmentation-pytorch/scripts/voc"                             # VOC数据集输出目录

    # 转换COCO数据集到Pascal VOC格式
    coco_to_voc_segmentation(coco_annotation_file, coco_image_dir, output_dir, category_id_mapping, category_colors)
# Out:
# loading annotations into memory...
# Done (t=0.00s)
# creating index...
# index created!
# Image Soil10.jpg contains category IDs: [0 4]
# Processed Soil10.jpg
# Image Stone3.jpg contains category IDs: [0 5]
# Processed Stone3.jpg
# Image Herb9.jpg contains category IDs: [0 1 2 5 6]
# Processed Herb9.jpg
# Image Grass20.jpg contains category IDs: [0 2 6]
# Processed Grass20.jpg
# Image Herb17.jpg contains category IDs: [0 2]
# Processed Herb17.jpg
# Image Woodchip10.jpg contains category IDs: [0 7]
# Processed Woodchip10.jpg
# Image Grass16.jpg contains category IDs: [0 1]
# Processed Grass16.jpg
# Image Litter9.jpg contains category IDs: [0 3]
# Processed Litter9.jpg
# Image Soil26.jpg contains category IDs: [0 4]
# Processed Soil26.jpg
# Image Stone12.jpg contains category IDs: [0 2 5 7]
# Processed Stone12.jpg
# Image Herb5.jpg contains category IDs: [0 1 2 5 6]
# Processed Herb5.jpg
# Image Soil30.jpg contains category IDs: [0 4]
# Processed Soil30.jpg
# Image Herb4.jpg contains category IDs: [0 2 4 7]
# Processed Herb4.jpg
# Image Soil31.jpg contains category IDs: [0 4]
# Processed Soil31.jpg
# Image Soil27.jpg contains category IDs: [0 4]
# Processed Soil27.jpg
# Image Grass17.jpg contains category IDs: [0 1 2 6]
# Processed Grass17.jpg
# Image Woodchip11.jpg contains category IDs: [0 7]
# Processed Woodchip11.jpg
# Image Herb8.jpg contains category IDs: [0 2 5]
# Processed Herb8.jpg
# Image Grass21.jpg contains category IDs: [0 1 2]
# Processed Grass21.jpg
# Image Grass1.jpg contains category IDs: [0 2]
# Processed Grass1.jpg
# Image Herb20.jpg contains category IDs: [0 2]
# Processed Herb20.jpg
# Image Stone2.jpg contains category IDs: [0 1 2 5 7]
# Processed Stone2.jpg
# Image Soil11.jpg contains category IDs: [0 4]
# Processed Soil11.jpg
# Image Herb11.jpg contains category IDs: [0 2]
# Processed Herb11.jpg
# Image Grass10.jpg contains category IDs: [0 1 2 5 6 7]
# Processed Grass10.jpg
# Image Soil20.jpg contains category IDs: [0 4]
# Processed Soil20.jpg
# Image Stone9.jpg contains category IDs: [0 2 5]
# Processed Stone9.jpg
# Image Herb3.jpg contains category IDs: [0 2]
# Processed Herb3.jpg
# Image Soil16.jpg contains category IDs: [0 4]
# Processed Soil16.jpg
# Image Stone22.jpg contains category IDs: [0 5]
# Processed Stone22.jpg
# Image Litter29.jpg contains category IDs: [0 3]
# Processed Litter29.jpg
# Image Woodchip20.jpg contains category IDs: [0 7]
# Processed Woodchip20.jpg
# Image Stone5.jpg contains category IDs: [0 2 5]
# Processed Stone5.jpg
# Image Grass6.jpg contains category IDs: [0 2]
# Processed Grass6.jpg
# Image Stone18.jpg contains category IDs: [0 5]
# Processed Stone18.jpg
# Image Woodchip7.jpg contains category IDs: [0 7]
# Processed Woodchip7.jpg
# Image Woodchip6.jpg contains category IDs: [0 7]
# Processed Woodchip6.jpg
# Image Grass7.jpg contains category IDs: [0 2]
# Processed Grass7.jpg
# Image Stone19.jpg contains category IDs: [0 1 2 5]
# Processed Stone19.jpg
# Image Stone4.jpg contains category IDs: [0 2 4 5]
# Processed Stone4.jpg
# Image Herb26.jpg contains category IDs: [0 1 2 5]
# Processed Herb26.jpg
# Image Woodchip21.jpg contains category IDs: [0 7]
# Processed Woodchip21.jpg
# Image Wood10.jpg contains category IDs: [0 6]
# Processed Wood10.jpg
# Image Litter2.jpg contains category IDs: [0 2 7]
# Processed Litter2.jpg
# Image Soil1.jpg contains category IDs: [0 4]
# Processed Soil1.jpg
# Image Soil17.jpg contains category IDs: [0 4]
# Processed Soil17.jpg
# Image Herb2.jpg contains category IDs: [0 2 7]
# Processed Herb2.jpg
# Image Stone15.jpg contains category IDs: [0 2 5]
# Processed Stone15.jpg
# Image Wood7.jpg contains category IDs: [0 6 7]
# Processed Wood7.jpg
# Image Soil21.jpg contains category IDs: [0 4]
# Processed Soil21.jpg
# Image Grass11.jpg contains category IDs: [0 1 2]
# Processed Grass11.jpg
# Image Herb10.jpg contains category IDs: [0 2]
# Processed Herb10.jpg
# Image Woodchip9.jpg contains category IDs: [0 7]
# Processed Woodchip9.jpg
# Image Herb1.jpg contains category IDs: [0 2 5 6]
# Processed Herb1.jpg
# Image Stone16.jpg contains category IDs: [0 5]
# Processed Stone16.jpg
# Image Wood4.jpg contains category IDs: [0 6]
# Processed Wood4.jpg
# Image Soil22.jpg contains category IDs: [0 4]
# Processed Soil22.jpg
# Image Grass12.jpg contains category IDs: [0 1 2 6]
# Processed Grass12.jpg
# Image Soil18.jpg contains category IDs: [0 4]
# Processed Soil18.jpg
# Image Woodchip14.jpg contains category IDs: [0 7]
# Processed Woodchip14.jpg
# Image Herb13.jpg contains category IDs: [0 2]
# Processed Herb13.jpg
# Image Woodchip5.jpg contains category IDs: [0 7]
# Processed Woodchip5.jpg
# Image Litter11.jpg contains category IDs: [0 3]
# Processed Litter11.jpg
# Image Grass4.jpg contains category IDs: [0 1 2]
# Processed Grass4.jpg
# Image Herb25.jpg contains category IDs: [0 2 4]
# Processed Herb25.jpg
# Image Wood13.jpg contains category IDs: [0 6]
# Processed Wood13.jpg
# Image Wood8.jpg contains category IDs: [0 6]
# Processed Wood8.jpg
# Image Stone20.jpg contains category IDs: [0 2 5]
# Processed Stone20.jpg
# Image Litter1.jpg contains category IDs: [0 1 2 5 6]
# Processed Litter1.jpg
# Image Soil2.jpg contains category IDs: [0 4]
# Processed Soil2.jpg
# Image Soil14.jpg contains category IDs: [0 4]
# Processed Soil14.jpg
# Image Woodchip18.jpg contains category IDs: [0 7]
# Processed Woodchip18.jpg
# Image Woodchip19.jpg contains category IDs: [0 7]
# Processed Woodchip19.jpg
# Image Soil15.jpg contains category IDs: [0 4]
# Processed Soil15.jpg
# Image Soil3.jpg contains category IDs: [0 4]
# Processed Soil3.jpg
# Image Stone21.jpg contains category IDs: [0 1 2 4 5]
# Processed Stone21.jpg
# Image Wood9.jpg contains category IDs: [0 1 4 6]
# Processed Wood9.jpg
# Image Stone6.jpg contains category IDs: [0 1 5 6]
# Processed Stone6.jpg
# Image Litter10.jpg contains category IDs: [0 3]
# Processed Litter10.jpg
# Image Woodchip4.jpg contains category IDs: [0 7]
# Processed Woodchip4.jpg
# Image Herb12.jpg contains category IDs: [0 2]
# Processed Herb12.jpg
# Image Soil19.jpg contains category IDs: [0 4]
# Processed Soil19.jpg
# Image Grass13.jpg contains category IDs: [0 1 7]
# Processed Grass13.jpg
# Image Soil23.jpg contains category IDs: [0 4]
# Processed Soil23.jpg
# Image Wood5.jpg contains category IDs: [0 6]
# Processed Wood5.jpg
# Image Stone17.jpg contains category IDs: [0 5]
# Processed Stone17.jpg
# Image Grass9.jpg contains category IDs: [0 1 2]
# Processed Grass9.jpg
# Image Woodchip3.jpg contains category IDs: [0 7]
# Processed Woodchip3.jpg
# Image Grass2.jpg contains category IDs: [0 1 2]
# Processed Grass2.jpg
# Image Herb23.jpg contains category IDs: [0 2 5 6]
# Processed Herb23.jpg
# Image Stone1.jpg contains category IDs: [0 5]
# Processed Stone1.jpg
# Image Wood15.jpg contains category IDs: [0 6]
# Processed Wood15.jpg
# Image Soil28.jpg contains category IDs: [0 4]
# Processed Soil28.jpg
# Image Soil4.jpg contains category IDs: [0 4]
# Processed Soil4.jpg
# Image Grass18.jpg contains category IDs: [0 1 5]
# Processed Grass18.jpg
# Image Soil12.jpg contains category IDs: [0 2 4]
# Processed Soil12.jpg
# Image Stone10.jpg contains category IDs: [0 1 2 4 5 6]
# Processed Stone10.jpg
# Image Wood2.jpg contains category IDs: [0 6]
# Processed Wood2.jpg
# Image Grass14.jpg contains category IDs: [0 1 4 5]
# Processed Grass14.jpg
# Image Woodchip12.jpg contains category IDs: [0 7]
# Processed Woodchip12.jpg
# Image Herb14.jpg contains category IDs: [0 2]
# Processed Herb14.jpg
# Image Grass15.jpg contains category IDs: [0 1 2 5 6]
# Processed Grass15.jpg
# Image Soil25.jpg contains category IDs: [0 1 4 5]
# Processed Soil25.jpg
# Image Wood3.jpg contains category IDs: [0 1 2 4 6]
# Processed Wood3.jpg
# Image Stone11.jpg contains category IDs: [0 2 5]
# Processed Stone11.jpg
# Image Herb6.jpg contains category IDs: [0 2]
# Processed Herb6.jpg
# Image Herb18.jpg contains category IDs: [0 2]
# Processed Herb18.jpg
# Image Soil13.jpg contains category IDs: [0 4]
# Processed Soil13.jpg
# Image Grass19.jpg contains category IDs: [0 2 5]
# Processed Grass19.jpg
# Image Litter6.jpg contains category IDs: [0 3]
# Processed Litter6.jpg
# Image Soil29.jpg contains category IDs: [0 4]
# Processed Soil29.jpg
# Image Herb22.jpg contains category IDs: [0 2]
# Processed Herb22.jpg
# Image Grass3.jpg contains category IDs: [0 1]
# Processed Grass3.jpg
# Image Woodchip2.jpg contains category IDs: [0 7]
# Processed Woodchip2.jpg
